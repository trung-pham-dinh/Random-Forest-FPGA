# %%
from pynq import Overlay
ol = Overlay('overlay/dma_fifo_gpio_test/random_forest.bit')

# %%
ol.axi_dma_0?

# %%
ol.ip_dict
# Out:
# {'axi_dma_0': {'addr_range': 65536,
#   'device': <pynq.pl_server.device.XlnkDevice at 0xb3a9f930>,
#   'driver': pynq.lib.dma.DMA,
#   'fullpath': 'axi_dma_0',
#   'gpio': {},
#   'interrupts': {},
#   'mem_id': 'S_AXI_LITE',
#   'parameters': {'C_BASEADDR': '0x40400000',
#    'C_DLYTMR_RESOLUTION': '125',
#    'C_ENABLE_MULTI_CHANNEL': '0',
#    'C_FAMILY': 'zynq',
#    'C_HIGHADDR': '0x4040FFFF',
#    'C_INCLUDE_MM2S': '0',
#    'C_INCLUDE_MM2S_DRE': '0',
#    'C_INCLUDE_MM2S_SF': '1',
#    'C_INCLUDE_S2MM': '1',
#    'C_INCLUDE_S2MM_DRE': '0',
#    'C_INCLUDE_S2MM_SF': '1',
#    'C_INCLUDE_SG': '0',
#    'C_INCREASE_THROUGHPUT': '0',
#    'C_MICRO_DMA': '0',
#    'C_MM2S_BURST_SIZE': '16',
#    'C_M_AXIS_MM2S_CNTRL_TDATA_WIDTH': '32',
#    'C_M_AXIS_MM2S_TDATA_WIDTH': '32',
#    'C_M_AXI_MM2S_ADDR_WIDTH': '32',
#    'C_M_AXI_MM2S_DATA_WIDTH': '32',
#    'C_M_AXI_S2MM_ADDR_WIDTH': '32',
#    'C_M_AXI_S2MM_DATA_WIDTH': '32',
#    'C_M_AXI_SG_ADDR_WIDTH': '32',
# ...

# %%
dma = ol.axi_dma_0
dma_recv = ol.axi_dma_0.recvchannel
dma_send = ol.axi_dma_0.sendchannel

# %%
from pynq import allocate
import numpy as np

data_size = 100

# %%
input_buffer = allocate(shape=(data_size,), dtype=np.uint32)

# %%
for i in range(data_size):
    input_buffer[i] = i + 0xcafe0000

# %%
for i in range(10):
    print(hex(input_buffer[i]))
# Out:
# 0xcafe0000
# 0xcafe0001
# 0xcafe0002
# 0xcafe0003
# 0xcafe0004
# 0xcafe0005
# 0xcafe0006
# 0xcafe0007
# 0xcafe0008
# 0xcafe0009

# %%
dma_send.transfer(input_buffer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d3ee49bfa76b> in <module>()
# ----> 1 dma_send.transfer(input_buffer)
#
# NameError: name 'dma_send' is not defined

# %%
output_buffer = allocate(shape=(data_size,), dtype=np.uint32)

for i in range(10):
    print('0x' + format(output_buffer[i], '02x'))
# Out:
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00

# %%
from pynq import GPIO

start = GPIO(GPIO.get_gpio_pin(0), 'out')
debug_toggle = GPIO(GPIO.get_gpio_pin(1), 'in')
debug_ready = GPIO(GPIO.get_gpio_pin(2), 'in')

# %%
start.write(0)
start.write(1)

# %%
debug_toggle.read()
# Out:
# 1

# %%
debug_ready.read()
# Out:
# 1

# %%
dma_recv.transfer(output_buffer)
for i in range(100):
    print('0x' + format(output_buffer[i], '02x'))
# Out:
# 0x00
# 0x01
# 0x02
# 0x03
# 0x04
# 0x05
# 0x06
# 0x07
# 0x08
# 0x09
# 0x0a
# 0x0b
# 0x0c
# 0x0d
# 0x0e
# 0x0f
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00

# %%
type(dma_recv)
# Out:
# pynq.lib.dma._SDMAChannel

# %%
type(dma_send)
# Out:
# NoneType

# %%
for i in range(100):
    print('0x' + format(output_buffer[i], '02x'))
# Out:
# 0x00
# 0x01
# 0x02
# 0x03
# 0x04
# 0x05
# 0x06
# 0x07
# 0x08
# 0x09
# 0x0a
# 0x0b
# 0x0c
# 0x0d
# 0x0e
# 0x0f
# 0x00
# 0x01
# 0x02
# 0x03
# 0x04
# 0x05
# 0x06
# 0x07
# 0x08
# 0x09
# 0x0a
# 0x0b
# 0x0c
# 0x0d
# 0x0e
# 0x0f
# 0x00
# 0x01
# 0x02
# 0x03
# 0x04
# 0x05
# 0x06
# 0x07
# 0x08
# 0x09
# 0x0a
# 0x0b
# 0x0c
# 0x0d
# 0x0e
# 0x0f
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00
# 0x00

# %%
dma_recv.idle
# Out:
# False

# %%
# TLAST is needed to let DMA knows if it has read all data through FIFO (DMA does not detect end of data by FIFO empty)
# TLAST and TVALID must be asserted together if data is the last one
# TKEEP is needed to let DMA knows if bytes in data are valid
# IP SLICE must be used to solve error of GPIO. GPIO_OUT[i] and GPIO_IN[i] uses same physical pin
